# %% [markdown]
# # Exploratory Data Analysis on Dataset - Terrorism

# %% [markdown]
# ## Objective
# ### As a security/defense analyst, trying to find out the hot zones of terrorism.

# %% [markdown]
# ## Dataset Link :  https://bit.ly/2TK5Xn5

# %% [markdown]
# ## Importing  libraries and Dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("globalterrorism.csv", encoding='ISO-8859-1')
# Out:
# D:\Anaconda\Installed\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
# The first 10 observations of the data set were accessed.

df.head(10)
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
# 5  197001010002   1970       1     1        NaN         0        NaN      217
# 6  197001020001   1970       1     2        NaN         0        NaN      218
# 7  197001020002   1970       1     2        NaN         0        NaN      217
# 8  197001020003   1970       1     2        NaN         0        NaN      217
# 9  197001030001   1970       1     3        NaN         0        NaN      217
#
#           country_txt  region  ...  \
# 0  Dominican Republic       2  ...
# 1              Mexico       1  ...
# ...

# %%
df.shape
# Out:
# (181691, 135)

# %%
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
df.isnull().any()
# Out:
# eventid       False
# iyear         False
# imonth        False
# iday          False
# approxdate     True
#               ...
# INT_LOG       False
# INT_IDEO      False
# INT_MISC      False
# INT_ANY       False
# related        True
# Length: 135, dtype: bool

# %% [markdown]
# # Top 10 Countries with Most Terrorist attacks

# %%
print(df['country_txt'].value_counts().head(10))
# Out:
# Iraq              24636
# Pakistan          14368
# Afghanistan       12731
# India             11960
# Colombia           8306
# Philippines        6908
# Peru               6096
# El Salvador        5320
# United Kingdom     5235
# Turkey             4292
# Name: country_txt, dtype: int64

# %%
countries=df['country_txt'].value_counts()[:10].index
values=df['country_txt'].value_counts()[:10].values
plt.figure(figsize=(15,10))
s=pd.Series(values,index=countries).plot(kind='barh',color='red')
plt.title('Countries with Most Terrorist Attacks',fontsize=30)
# Out:
# Text(0.5, 1.0, 'Countries with Most Terrorist Attacks')

# %% [markdown]
# ### 1. Most Affected Country : Iraq
#
# ### 2. Among top 10 affected countries five are asian

# %% [markdown]
# # Regions With Most Terrorist Attacks

# %%
print(df['region_txt'].value_counts().head(10))
# Out:
# Middle East & North Africa     50474
# South Asia                     44974
# South America                  18978
# Sub-Saharan Africa             17550
# Western Europe                 16639
# Southeast Asia                 12485
# Central America & Caribbean    10344
# Eastern Europe                  5144
# North America                   3456
# East Asia                        802
# Name: region_txt, dtype: int64

# %%
regions=df['region_txt'].value_counts()[:10].index
values=df['region_txt'].value_counts()[:10].values
plt.figure(figsize=(15,10))
s=pd.Series(values,index=regions).plot(kind='barh',color='red')
plt.title('Regions with Most Terrorist Attacks',fontsize=30)
# Out:
# Text(0.5, 1.0, 'Regions with Most Terrorist Attacks')

# %% [markdown]
# ### Most Affected Region : Middle East & North Africa

# %% [markdown]
# # States with most terrorist attacks

# %%
print(df['provstate'].value_counts().head(10))
# Out:
# Baghdad               7645
# Northern Ireland      4498
# Unknown               4290
# Balochistan           3710
# Saladin               3411
# Al Anbar              3299
# Nineveh               3241
# Sindh                 3206
# Khyber Pakhtunkhwa    3084
# Diyala                3041
# Name: provstate, dtype: int64

# %%
states=df['provstate'].value_counts()[:10].index
values_states=df['provstate'].value_counts()[:10].values
plt.figure(figsize=(15,10))
s=pd.Series(values_states,index=states).plot(kind='barh',color='red')
plt.title('States with Most Terrorist Attacks',fontsize=30)
# Out:
# Text(0.5, 1.0, 'States with Most Terrorist Attacks')

# %% [markdown]
# ### Most Affected State: Baghdad

# %% [markdown]
# # Cities with Most Terrorist Attacks

# %%
print(df['city'].value_counts().head(10))
# Out:
# Unknown         9775
# Baghdad         7589
# Karachi         2652
# Lima            2359
# Mosul           2265
# Belfast         2171
# Santiago        1621
# Mogadishu       1581
# San Salvador    1558
# Istanbul        1048
# Name: city, dtype: int64

# %%
cities=df['city'].value_counts()[:10].index
values_cities=df['city'].value_counts()[:10].values
plt.figure(figsize=(15,10))
s=pd.Series(values_cities,index=cities).plot(kind='barh',color='red')
plt.title('Cities with Most Terrorist Attacks',fontsize=30)
# Out:
# Text(0.5, 1.0, 'Cities with Most Terrorist Attacks')

# %% [markdown]
# ### Most Affected City : Baghdad

# %% [markdown]
# # Number of Terrorist attacks through all these Years

# %%
print(df['iyear'].value_counts().head(10))
# Out:
# 2014    16903
# 2015    14965
# 2016    13587
# 2013    12036
# 2017    10900
# 2012     8522
# 2011     5076
# 1992     5071
# 2010     4826
# 2008     4805
# Name: iyear, dtype: int64

# %%
index=df['iyear'].value_counts()[:10].index
year=df['iyear'].value_counts()[:10].values

plt.figure(figsize=(15,10))
sns.barplot(index, values)
plt.title('Year vs Number of Terrorist Attacks',fontsize=30)
plt.xlabel('Year')
plt.show()
# Out:
# D:\Anaconda\Installed\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### Year with most number of Terrorist attacks : 2014

# %% [markdown]
# ## Attack per year

# %%
plt.figure(figsize=(15,10))
sns.countplot(df["iyear"],palette='Set2')
plt.xticks(rotation=90)
plt.title("Attack per year",fontsize=30)
plt.show()
# Out:
# D:\Anaconda\Installed\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Indian States With Most Terrorist Attacks

# %%
data_istates=df[df['country_txt']=='India']['provstate']
data_istates.value_counts()[:10]
# Out:
# Jammu and Kashmir    2454
# Assam                1151
# Manipur              1100
# Chhattisgarh          979
# Punjab                949
# Jharkhand             887
# Bihar                 688
# West Bengal           650
# Odisha                428
# Maharashtra           302
# Name: provstate, dtype: int64

# %%
index_states=df[df['country_txt']=='India']['provstate'].value_counts()[:10].index
indian_states=df[df['country_txt']=='India']['provstate'].value_counts()[:10].values

plt.figure(figsize=(15,10))
plt.bar(index_states,indian_states, color='#03a9f4')
plt.title('Indian States with most terrorist attacks',fontsize=30)
plt.show()

# %% [markdown]
# ### Most affected Indian State : Jammu and Kashmir

# %% [markdown]
# # Indian Cities With Most Terrorist Attacks

# %%
data_iscity=df[df['country_txt']=='India']['city']
data_iscity.value_counts()[:10]
# Out:
# Srinagar     658
# Unknown      624
# Imphal       426
# New Delhi    157
# Amritsar     138
# Sopore       102
# Ludhiana      77
# Guwahati      77
# Anantnag      76
# Jammu         57
# Name: city, dtype: int64

# %%
index_city=df[df['country_txt']=='India']['city'].value_counts()[:10].index
indian_city=df[df['country_txt']=='India']['city'].value_counts()[:10].values

plt.figure(figsize=(15,10))
plt.bar(index_city,indian_city, color='#03a9f4')
plt.title('Indian Cities with most terrorist attacks',fontsize=30)
plt.show()

# %% [markdown]
# ### Most affected Indian City : Srinagar

# %% [markdown]
# # Weapons used : Worldwide vs India

# %%
weapons_worldwide=df['weaptype1_txt'].value_counts()[:5].index
values_weapons_worldwide=df['weaptype1_txt'].value_counts()[:5].values

weapons_india=df[df['country_txt']=='India']['weaptype1_txt'].value_counts()[:5].index
values_weapons_india=df[df['country_txt']=='India']['weaptype1_txt'].value_counts()[:5].values

plt.figure(figsize=(15,10))
plt.subplot(1, 2, 1)
plt.bar(weapons_worldwide,values_weapons_worldwide, color='red')
plt.title('Weapons mostly used Worldwide',fontsize=20)


plt.subplot(1, 2, 2)
plt.bar(weapons_india,values_weapons_india, color='#03a9f4')
plt.title('Weapons mostly used in India',fontsize=20)
plt.show()

# %% [markdown]
# ### As we can see that in both cases the mostly used weapon comes in the form of Explosives

# %% [markdown]
# # Types of Target : Worldwide vs India

# %%
targets_worldwide=df['targtype1_txt'].value_counts()[:5].index
values_targets_worldwide=df['targtype1_txt'].value_counts()[:5].values

targets_india=df[df['country_txt']=='India']['targtype1_txt'].value_counts()[:5].index
values_targets_india=df[df['country_txt']=='India']['targtype1_txt'].value_counts()[:5].values

plt.figure(figsize=(19,8))
plt.subplot(1, 2, 1)
plt.bar(targets_worldwide,values_targets_worldwide, color='red')
plt.title('Type of Targets Worldwide',fontsize=20)


plt.subplot(1, 2, 2)
plt.bar(targets_india,values_targets_india, color='#03a9f4')
plt.title('Type of Targets in India',fontsize=20)
plt.show()

# %% [markdown]
# ### So we can see that in both the cases Private Citizens and property were targeted the most.

# %% [markdown]
# # Top 3 involved Terrorist Groups : Worldwide vs India

# %%
groups_worldwide=df['gname'].value_counts()[:3].index
values_groups_worldwide=df['gname'].value_counts()[:3].values

groups_india=df[df['country_txt']=='India']['gname'].value_counts()[:3].index
values_groups_india=df[df['country_txt']=='India']['gname'].value_counts()[:3].values

plt.figure(figsize=(19,8))
plt.subplot(1, 2, 1)
plt.bar(groups_worldwide,values_groups_worldwide, color='red')
plt.title('Involved Terrorist Groups Worldwide',fontsize=20)


plt.subplot(1, 2, 2)
plt.bar(groups_india,values_groups_india, color='#03a9f4')
plt.title('Involved Terrorist Groups in India',fontsize=20)
plt.show()

# %% [markdown]
# ### In both the cases the group causing the most attacks could not be known but apart from them Taliban is seen to be causing most of the problems worldwide whereas in india it is caused mostly by CPI-Maoist.

# %% [markdown]
# # Conclusion:
#
# ## 1.    Most affected country: Iraq
# ## 2.    Most affected region : Middle East & North Africa
# ## 3.    Most affected state : Baghdad
# ## 4.    Most affected city : Baghdad
# ## 5.    Year with most terrorist attacks : 2014
# ## 6.    Most affected Indian State : Jammu & Kashmir
# ## 7.    Most affected Indian City : Srinagar
# ## 8.    Main weapons used for terrorism  : Explosives
# ## 9.    Main target of terrorism : Private Citizens and property
# ## 10.  Most involved terrorist group worldwide : Taliban
# ## 11.  Most involved terrorist group in india : CPI-Maoist
